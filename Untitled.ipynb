# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set(style="darkgrid")

# %%
df = pd.read_csv("LoanStats3b.csv")
desc = pd.read_excel("LCDataDictionary.xlsx")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (47,123,124,125,128,129,130,133) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df
# Out:
#         loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  \
# 0           27050        27050     27050.000000   36 months     10.99
# 1            4800         4800      4800.000000   36 months     10.99
# 2            7550         7550      7550.000000   36 months     16.24
# 3           27600        27600     27600.000000   60 months     19.97
# 4            8000         8000      8000.000000   36 months     10.99
# 5           15000        15000     15000.000000   36 months     14.47
# 6           12000        12000     12000.000000   36 months      7.62
# 7            9750         9750      9750.000000   36 months     13.98
# 8           11100        11100     11100.000000   36 months     14.98
# 9           15000        15000     15000.000000   36 months      8.90
# 10          24000        24000     24000.000000   36 months     13.53
# 11          12000        12000     12000.000000   36 months     13.53
# 12          14000        14000     14000.000000   36 months     12.85
# 13           3000         3000      3000.000000   36 months     12.85
# 14          12000        12000     12000.000000   36 months      6.62
# 15          12000        12000     12000.000000   36 months     11.99
# 16          12000        12000     12000.000000   36 months     10.99
# 17          20800        20800     20800.000000   36 months     13.53
# 18          10000        10000     10000.000000   36 months      9.67
# 19          11500        11500     11500.000000   60 months     22.90
# 20          28000        28000     28000.000000   36 months      7.62
# 21          16000        16000     16000.000000   36 months      7.62
# 22          17475        17475     17475.000000   60 months     21.48
# 23          20000        20000     20000.000000   36 months     13.98
# 24          10000        10000     10000.000000   60 months     14.98
# 25           7500         7500      7500.000000   36 months      7.62
# 26           4000         4000      4000.000000   36 months     16.24
# 27          10400        10400     10400.000000   60 months     17.57
# 28          14825        14825     14825.000000   36 months     18.25
# 29          12000        12000     12000.000000   60 months     16.24
# ...           ...          ...              ...         ...       ...
# 188151      20100        20100     20100.000000   36 months     17.27
# 188152      19200        19200     19175.000000   60 months     17.58
# 188153      16400        16400     16400.000000   36 months     16.29
# 188154      10000        10000     10000.000000   36 months     11.71
# 188155      15000        15000     15000.000000   36 months      6.03
# 188156      35000        35000     33429.996633   60 months     13.49
# 188157      12000        12000     12000.000000   36 months      6.03
# 188158      20750        20750     20725.000000   60 months     12.42
# 188159      22000        22000     22000.000000   60 months     12.42
# 188160       6600         6600      6600.000000   60 months     17.58
# 188161      22000        22000     22000.000000   60 months     14.65
# 188162       7500         7500      7500.000000   36 months      6.03
# 188163      33950        33950     31311.688766   60 months     15.96
# 188164       4000         4000      4000.000000   36 months     14.65
# 188165      18000        18000     10075.000000   60 months     22.35
# 188166      10000        10000     10000.000000   36 months      9.91
# 188167      35000        21775     20375.659759   60 months     22.74
# 188168      20000        13675      6675.000000   60 months     19.91
# 188169      18000        18000     16737.957469   60 months     17.58
# 188170      17500        16800     16775.000000   60 months     22.74
# 188171      35000        22550     22550.000000   60 months     14.27
# 188172      24000        24000     22961.954975   60 months     12.69
# 188173       8650         8650      8625.000000   36 months     14.65
# 188174      20000        12675     12675.000000   60 months     14.27
# 188175      12000        12000     11975.000000   36 months      7.90
# 188176      20500        20500     20500.000000   36 months     16.77
# 188177      15000        15000     15000.000000   36 months     15.27
# 188178      35000        35000     35000.000000   36 months     15.96
# 188179      12000        12000     12000.000000   36 months     16.29
# 188180      12000         7775      7775.000000   60 months     15.27
#
#         installment grade sub_grade emp_length home_ownership   ...    \
# 0            885.46     B        B2  10+ years            OWN   ...
# 1            157.13     B        B2    2 years       MORTGAGE   ...
# 2            266.34     C        C5    3 years           RENT   ...
# 3            730.78     D        D5    6 years       MORTGAGE   ...
# 4            261.88     B        B2    2 years       MORTGAGE   ...
# 5            516.10     C        C2  10+ years           RENT   ...
# 6            373.94     A        A3    3 years       MORTGAGE   ...
# 7            333.14     C        C1     1 year           RENT   ...
# 8            384.68     C        C3  10+ years       MORTGAGE   ...
# 9            476.30     A        A5    2 years       MORTGAGE   ...
# 10           814.80     B        B5  10+ years       MORTGAGE   ...
# 11           407.40     B        B5  10+ years           RENT   ...
# 12           470.71     B        B4    4 years           RENT   ...
# 13           100.87     B        B4  10+ years           RENT   ...
# 14           368.45     A        A2  10+ years       MORTGAGE   ...
# 15           398.52     B        B3  10+ years       MORTGAGE   ...
# 16           392.81     B        B2    4 years           RENT   ...
# 17           706.16     B        B5  10+ years           RENT   ...
# 18           321.13     B        B1    7 years       MORTGAGE   ...
# 19           323.54     E        E4    4 years           RENT   ...
# 20           872.52     A        A3    5 years       MORTGAGE   ...
# 21           498.59     A        A3   < 1 year       MORTGAGE   ...
# 22           477.49     E        E2  10+ years       MORTGAGE   ...
# 23           683.36     C        C1  10+ years       MORTGAGE   ...
# 24           237.80     C        C3    2 years           RENT   ...
# 25           233.72     A        A3    8 years       MORTGAGE   ...
# 26           141.11     C        C5  10+ years       MORTGAGE   ...
# 27           261.67     D        D2    2 years           RENT   ...
# 28           537.83     D        D3   < 1 year           RENT   ...
# 29           293.35     C        C5    2 years           RENT   ...
# ...             ...   ...       ...        ...            ...   ...
# 188151       719.33     D        D3  10+ years            OWN   ...
# 188152       483.18     D        D4  10+ years           RENT   ...
# 188153       578.93     D        D1    4 years           RENT   ...
# 188154       330.76     B        B3    5 years           RENT   ...
# 188155       456.54     A        A1    2 years       MORTGAGE   ...
# 188156       805.17     C        C1    7 years           RENT   ...
# 188157       365.23     A        A1    3 years           RENT   ...
# 188158       465.99     B        B4   < 1 year           RENT   ...
# 188159       494.06     B        B4     1 year           RENT   ...
# 188160       166.10     D        D4    7 years           RENT   ...
# 188161       519.35     C        C3     1 year           RENT   ...
# 188162       228.27     A        A1        NaN           RENT   ...
# 188163       824.88     C        C5    7 years       MORTGAGE   ...
# 188164       137.98     C        C3        NaN       MORTGAGE   ...
# 188165       500.73     F        F5    4 years           RENT   ...
# 188166       322.25     B        B1    3 years           RENT   ...
# 188167       610.60     G        G1  10+ years           RENT   ...
# 188168       361.62     E        E4  10+ years           RENT   ...
# 188169       452.98     D        D4  10+ years       MORTGAGE   ...
# 188170       471.10     G        G1    6 years       MORTGAGE   ...
# 188171       527.87     C        C2  10+ years       MORTGAGE   ...
# 188172       542.28     B        B5    2 years           RENT   ...
# 188173       298.38     C        C3    9 years           RENT   ...
# 188174       296.71     C        C2  10+ years       MORTGAGE   ...
# 188175       375.49     A        A4    3 years       MORTGAGE   ...
# 188176       728.54     D        D2    7 years           RENT   ...
# 188177       521.97     C        C4    3 years           RENT   ...
# 188178      1229.81     C        C5    3 years       MORTGAGE   ...
# 188179       423.61     D        D1        NaN       MORTGAGE   ...
# 188180       186.08     C        C4    7 years           RENT   ...
#
#         hardship_last_payment_amount disbursement_method debt_settlement_flag  \
# 0                                NaN                Cash                    N
# 1                                NaN                Cash                    N
# 2                                NaN                Cash                    N
# 3                                NaN                Cash                    N
# 4                                NaN                Cash                    N
# 5                                NaN                Cash                    N
# 6                                NaN                Cash                    N
# 7                                NaN                Cash                    N
# 8                                NaN                Cash                    N
# 9                                NaN                Cash                    N
# 10                               NaN                Cash                    N
# 11                               NaN                Cash                    N
# 12                               NaN                Cash                    N
# 13                               NaN                Cash                    N
# 14                               NaN                Cash                    N
# 15                               NaN                Cash                    N
# 16                               NaN                Cash                    N
# 17                               NaN                Cash                    N
# 18                               NaN                Cash                    N
# 19                               NaN                Cash                    N
# 20                               NaN                Cash                    N
# 21                               NaN                Cash                    N
# 22                               NaN                Cash                    N
# 23                               NaN                Cash                    N
# 24                               NaN                Cash                    N
# 25                               NaN                Cash                    N
# 26                               NaN                Cash                    N
# 27                               NaN                Cash                    N
# 28                               NaN                Cash                    N
# 29                               NaN                Cash                    N
# ...                              ...                 ...                  ...
# 188151                           NaN                Cash                    N
# 188152                           NaN                Cash                    N
# 188153                           NaN                Cash                    N
# 188154                           NaN                Cash                    N
# 188155                           NaN                Cash                    N
# 188156                           NaN                Cash                    N
# 188157                           NaN                Cash                    N
# 188158                           NaN                Cash                    N
# 188159                           NaN                Cash                    N
# 188160                           NaN                Cash                    N
# 188161                           NaN                Cash                    N
# 188162                           NaN                Cash                    N
# 188163                           NaN                Cash                    N
# 188164                           NaN                Cash                    N
# 188165                           NaN                Cash                    N
# 188166                           NaN                Cash                    N
# 188167                           NaN                Cash                    N
# 188168                           NaN                Cash                    N
# 188169                           NaN                Cash                    N
# 188170                           NaN                Cash                    N
# 188171                           NaN                Cash                    N
# 188172                           NaN                Cash                    N
# 188173                           NaN                Cash                    N
# 188174                           NaN                Cash                    N
# 188175                           NaN                Cash                    N
# 188176                           NaN                Cash                    N
# 188177                           NaN                Cash                    N
# 188178                           NaN                Cash                    N
# 188179                           NaN                Cash                    N
# 188180                           NaN                Cash                    N
#
#        debt_settlement_flag_date settlement_status settlement_date  \
# 0                            NaN               NaN             NaN
# 1                            NaN               NaN             NaN
# 2                            NaN               NaN             NaN
# 3                            NaN               NaN             NaN
# 4                            NaN               NaN             NaN
# 5                            NaN               NaN             NaN
# 6                            NaN               NaN             NaN
# 7                            NaN               NaN             NaN
# 8                            NaN               NaN             NaN
# 9                            NaN               NaN             NaN
# 10                           NaN               NaN             NaN
# 11                           NaN               NaN             NaN
# 12                           NaN               NaN             NaN
# 13                           NaN               NaN             NaN
# 14                           NaN               NaN             NaN
# 15                           NaN               NaN             NaN
# 16                           NaN               NaN             NaN
# 17                           NaN               NaN             NaN
# 18                           NaN               NaN             NaN
# 19                           NaN               NaN             NaN
# 20                           NaN               NaN             NaN
# 21                           NaN               NaN             NaN
# 22                           NaN               NaN             NaN
# 23                           NaN               NaN             NaN
# 24                           NaN               NaN             NaN
# 25                           NaN               NaN             NaN
# 26                           NaN               NaN             NaN
# 27                           NaN               NaN             NaN
# 28                           NaN               NaN             NaN
# 29                           NaN               NaN             NaN
# ...                          ...               ...             ...
# 188151                       NaN               NaN             NaN
# 188152                       NaN               NaN             NaN
# 188153                       NaN               NaN             NaN
# 188154                       NaN               NaN             NaN
# 188155                       NaN               NaN             NaN
# 188156                       NaN               NaN             NaN
# 188157                       NaN               NaN             NaN
# 188158                       NaN               NaN             NaN
# 188159                       NaN               NaN             NaN
# 188160                       NaN               NaN             NaN
# 188161                       NaN               NaN             NaN
# 188162                       NaN               NaN             NaN
# 188163                       NaN               NaN             NaN
# 188164                       NaN               NaN             NaN
# 188165                       NaN               NaN             NaN
# 188166                       NaN               NaN             NaN
# 188167                       NaN               NaN             NaN
# 188168                       NaN               NaN             NaN
# 188169                       NaN               NaN             NaN
# 188170                       NaN               NaN             NaN
# 188171                       NaN               NaN             NaN
# 188172                       NaN               NaN             NaN
# 188173                       NaN               NaN             NaN
# 188174                       NaN               NaN             NaN
# 188175                       NaN               NaN             NaN
# 188176                       NaN               NaN             NaN
# 188177                       NaN               NaN             NaN
# 188178                       NaN               NaN             NaN
# 188179                       NaN               NaN             NaN
# 188180                       NaN               NaN             NaN
#
#        settlement_amount  settlement_percentage  settlement_term  target
# 0                    NaN                    NaN              NaN       0
# 1                    NaN                    NaN              NaN       0
# 2                    NaN                    NaN              NaN       0
# 3                    NaN                    NaN              NaN       1
# 4                    NaN                    NaN              NaN       1
# 5                    NaN                    NaN              NaN       0
# 6                    NaN                    NaN              NaN       0
# 7                    NaN                    NaN              NaN       0
# 8                    NaN                    NaN              NaN       0
# 9                    NaN                    NaN              NaN       0
# 10                   NaN                    NaN              NaN       0
# 11                   NaN                    NaN              NaN       0
# 12                   NaN                    NaN              NaN       0
# 13                   NaN                    NaN              NaN       0
# 14                   NaN                    NaN              NaN       0
# 15                   NaN                    NaN              NaN       0
# 16                   NaN                    NaN              NaN       0
# 17                   NaN                    NaN              NaN       0
# 18                   NaN                    NaN              NaN       0
# 19                   NaN                    NaN              NaN       0
# 20                   NaN                    NaN              NaN       0
# 21                   NaN                    NaN              NaN       0
# 22                   NaN                    NaN              NaN       0
# 23                   NaN                    NaN              NaN       0
# 24                   NaN                    NaN              NaN       0
# 25                   NaN                    NaN              NaN       0
# 26                   NaN                    NaN              NaN       0
# 27                   NaN                    NaN              NaN       0
# 28                   NaN                    NaN              NaN       1
# 29                   NaN                    NaN              NaN       0
# ...                  ...                    ...              ...     ...
# 188151               NaN                    NaN              NaN       0
# 188152               NaN                    NaN              NaN       0
# 188153               NaN                    NaN              NaN       0
# 188154               NaN                    NaN              NaN       0
# 188155               NaN                    NaN              NaN       0
# 188156               NaN                    NaN              NaN       0
# 188157               NaN                    NaN              NaN       0
# 188158               NaN                    NaN              NaN       0
# 188159               NaN                    NaN              NaN       0
# 188160               NaN                    NaN              NaN       0
# 188161               NaN                    NaN              NaN       0
# 188162               NaN                    NaN              NaN       0
# 188163               NaN                    NaN              NaN       0
# 188164               NaN                    NaN              NaN       0
# 188165               NaN                    NaN              NaN       0
# 188166               NaN                    NaN              NaN       0
# 188167               NaN                    NaN              NaN       0
# 188168               NaN                    NaN              NaN       0
# 188169               NaN                    NaN              NaN       0
# 188170               NaN                    NaN              NaN       1
# 188171               NaN                    NaN              NaN       1
# 188172               NaN                    NaN              NaN       0
# 188173               NaN                    NaN              NaN       0
# 188174               NaN                    NaN              NaN       0
# 188175               NaN                    NaN              NaN       0
# 188176               NaN                    NaN              NaN       0
# 188177               NaN                    NaN              NaN       0
# 188178               NaN                    NaN              NaN       0
# 188179               NaN                    NaN              NaN       1
# 188180               NaN                    NaN              NaN       0
#
# [188181 rows x 132 columns]

# %%
df.groupby('loan_status').size()
# Out:
# loan_status
# Charged Off            29411
# Current                 5198
# Fully Paid            153283
# In Grace Period          128
# Late (16-30 days)         31
# Late (31-120 days)       130
# dtype: int64

# %%
column_desc = {}
for column in df.columns:
    column_desc[column] = str(*desc[desc['LoanStatNew'] == column]['Description'].values)

# %%
column_desc

# %%
df['issue_month'], df['issue_year'] = df['issue_d'].str.split('-', 1).str

# %%
df['default'] = [1 if i == "Charged Off" else 0 for i in df['loan_status']]

# %%
# ----------------------
#       Cleaning
# ----------------------

df['int_rate'] = df['int_rate'].str.replace("%", "")
df['int_rate'] = df['int_rate'].astype("float")

# Not useful data
not_useful = ['url', 'desc', 'policy_code', 'last_pymnt_d',
              'next_pymnt_d', 'earliest_cr_line', 'emp_title',
              'id', 'member_id', 'title', 'total_rec_int',
              'total_rec_late_fee', 'total_rec_prncp', 'zip_code']

df = df.drop(not_useful, axis=1)

# %%
# ----------------------
#       Handle NA
# ----------------------

msno.bar(df[model_features])
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-779-36b1ee52ffd6> in <module>()
#       3 # ----------------------
#       4
# ----> 5 msno.bar(df[model_features])
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/missingno/missingno.py in bar(df, figsize, fontsize, labels, log, color, inline, filter, n, p, sort)
#     245     ax3.grid(False)
#     246
# --> 247     for ax in [ax1, ax2, ax3]:
#     248         ax.spines['top'].set_visible(False)
#     249         ax.spines['right'].set_visible(False)
#
# UnboundLocalError: local variable 'ax2' referenced before assignment

# %%
df.dropna(subset=["bc_util"], inplace=True)

# %%
np.percentile(df['tot_hi_cred_lim'].dropna(axis=0), 10)
# Out:
# 24758.0

# %%
# df['bc_util'].fillna(0, inplace=True)
# df['bc_util'].fillna(np.percentile(df['bc_util'].dropna(axis=0), 10), inplace=True)
# df['percent_bc_gt_75'].fillna(np.percentile(df['percent_bc_gt_75'].dropna(axis=0), 10), inplace=True)
df['bc_open_to_buy'].fillna(np.percentile(df['bc_open_to_buy'].dropna(axis=0), 10), inplace=True)
# df['total_bc_limit'].fillna(np.percentile(df['total_bc_limit'].dropna(axis=0), 10), inplace=True)
df['tot_hi_cred_lim'].fillna(np.percentile(df['tot_hi_cred_lim'].dropna(axis=0), 10), inplace=True)
df['num_sats'].fillna(0, inplace=True)
df['annual_inc'].fillna(np.median(df['annual_inc']), inplace=True)
df['avg_cur_bal'].fillna(np.median(df['avg_cur_bal'].dropna(axis=0)), inplace=True)
df['total_bal_ex_mort'].fillna(np.median(df['total_bal_ex_mort']), inplace=True)
df['tot_cur_bal'].fillna(np.median(df['tot_cur_bal'].dropna(axis=0)), inplace=True)

credit_limit_groupby_annual_inc = df.groupby('annual_inc_bin')['total_il_high_credit_limit'].transform('mean')
df['total_il_high_credit_limit'].fillna(credit_limit_groupby_annual_inc, inplace=True)

# %%
# ----------------------
#       Binning
# ----------------------

df['bc_util_bin'] = pd.qcut(df['bc_util'], q=4, labels=["Quantile {}".format(i) for i in range(1,5)] , duplicates="drop")
df['installment_bin'] = pd.qcut(df['installment'], q=10, labels=["Quantile {}".format(i) for i in range(1,11)], duplicates="drop")
df['dti_bin'] = pd.qcut(df['dti'], q=10, labels=["Quantile {}".format(i) for i in range(1,11)], duplicates="drop")

df["bc_open_to_buy_bin"] = pd.qcut(df['bc_open_to_buy'], q=10, labels=["Quantile {}".format(i) for i in range(1,11)], duplicates="drop")
df["annual_inc_bin"] = pd.qcut(df['annual_inc'], q=10, labels=["Quantile {}".format(i) for i in range(1,11)], duplicates="drop")
df["mths_since_last_major_derog_bin"] = pd.qcut(df['mths_since_last_major_derog'], q=6, labels=["Quantile {}".format(i) for i in range(1,7)], duplicates="drop")
df["total_acc_bin"] = pd.qcut(df['total_acc'], q=6, labels=["Quantile {}".format(i) for i in range(1,7)], duplicates="drop")
df["revol_bal_bin"] = pd.qcut(df['revol_bal'], q=20, labels=["Quantile {}".format(i) for i in range(1,21)], duplicates="drop")
df["mo_sin_old_rev_tl_op_bin"] = pd.qcut(df['mo_sin_old_rev_tl_op'], q=10, labels=["Quantile {}".format(i) for i in range(1,11)], duplicates="drop")
df["num_il_tl_bin"] = pd.qcut(df["num_il_tl"], q=6, labels=["Quantile {}".format(i) for i in range(1,7)], duplicates="drop")

# %% [markdown]
# # Exploratory Data Analysis

# %%
nan_columns = []
for col in numerical.columns:
    col_vals = df[col].unique()
    if len(col_vals) == 1:
        if np.isnan(col_vals[0]):
            nan_columns.append(col)

# %%
set(numerical.columns).difference(set(nan_columns))
# Out:
# {'acc_now_delinq',
#  'acc_open_past_24mths',
#  'annual_inc',
#  'avg_cur_bal',
#  'bc_open_to_buy',
#  'bc_util',
#  'bc_util_bin',
#  'chargeoff_within_12_mths',
#  'collection_recovery_fee',
#  'collections_12_mths_ex_med',
#  'default',
#  'deferral_term',
#  'delinq_2yrs',
#  'delinq_amnt',
#  'dti',
#  'funded_amnt',
#  'funded_amnt_inv',
#  'hardship_amount',
#  'hardship_dpd',
#  'hardship_last_payment_amount',
#  'hardship_length',
#  'hardship_payoff_balance_amount',
#  'inq_last_6mths',
#  'installment',
#  'installment_bin',
#  'int_rate',
#  'last_pymnt_amnt',
#  'loan_amnt',
#  'mo_sin_old_il_acct',
#  'mo_sin_old_rev_tl_op',
#  'mo_sin_rcnt_rev_tl_op',
#  'mo_sin_rcnt_tl',
#  'mort_acc',
#  'mths_since_last_delinq',
#  'mths_since_last_major_derog',
#  'mths_since_last_record',
#  'mths_since_recent_bc',
#  'mths_since_recent_bc_dlq',
#  'mths_since_recent_inq',
#  'mths_since_recent_revol_delinq',
#  'num_accts_ever_120_pd',
#  'num_actv_bc_tl',
#  'num_actv_rev_tl',
#  'num_bc_sats',
#  'num_bc_tl',
#  'num_il_tl',
#  'num_op_rev_tl',
#  'num_rev_accts',
#  'num_rev_tl_bal_gt_0',
#  'num_sats',
#  'num_tl_120dpd_2m',
#  'num_tl_30dpd',
#  'num_tl_90g_dpd_24m',
#  'num_tl_op_past_12m',
#  'open_acc',
#  'orig_projected_additional_accrued_interest',
#  'out_prncp',
#  'out_prncp_inv',
#  'pct_tl_nvr_dlq',
#  'percent_bc_gt_75',
#  'pub_rec',
#  'pub_rec_bankruptcies',
#  'recoveries',
#  'revol_bal',
#  'settlement_amount',
#  'settlement_percentage',
#  'settlement_term',
#  'tax_liens',
#  'tot_coll_amt',
#  'tot_cur_bal',
#  'tot_hi_cred_lim',
#  'total_acc',
#  'total_bal_ex_mort',
#  'total_bc_limit',
#  'total_il_high_credit_limit',
#  'total_pymnt',
#  'total_pymnt_inv',
#  'total_rev_hi_lim'}

# %%
def column_info(col):
    print(column_desc[col])
    try:
        vals = (df[col].unique(), len(df[col].unique()), max(df[col].unique()))
    except:
        vals = (df[col].unique(), len(df[col].unique()), None)
    print("values: {}\nlength: {}\nmax: {}".format(*vals))

# %%
# n = 2
# grades_grouped = [grades[i:i+n] for i in range(0, len(grades), n)] 

def run_hist(input_df, col, bins, to_iterate, col_val, save=False, outliers=False, outlier_percentile=70):
    fig, ax = plt.subplots()
    if outliers:
        df_hist_orig = input_df[input_df[col] < np.percentile(input_df[col].dropna(), outlier_percentile)]
    else:
        df_hist_orig = input_df
    for grade in grades_grouped:
        df_hist = df_hist_orig
        try:
            df_hist = df_hist[df_hist['grade'].isin(grade)][col].dropna()
        except Exception as e:
            print(e)
        sns.distplot(df_hist, bins=bins, ax=ax, kde=False, label=", ".join(grade) + " Grades")
        ax.set_title("{} for {} loans".format(df[col].name.title(), col_val))
        ax.legend()

    if save:
        plt.savefig("histogram_grades_{}_{}_{}.png".format(col, to_iterate, col_val))

def iterate_hist_over_col_vals(to_iterate, column):
    for col_val in df[to_iterate].unique():
        input_df = df[df[to_iterate] == col_val]
        run_hist(input_df, column, bins=10, to_iterate=to_iterate, col_val=col_val, outliers=False, save=False)

iterate_hist_over_col_vals(to_iterate="annual_inc_bin", column="acc_open_past_24mths")

# %%
grades_group = {'A': 1, 'B':1,
                'C': 2, 'D':2,
                'E': 3, 'F':3, 'G':3}
df["grades_grouped"] = df['grade'].map(grades_group)

# %%
grades = sorted(df['grade'].unique())
rainbow = sns.color_palette("hls", 7)

def run_probabilities(col, grade):
    grade_ctab = pd.crosstab(df[col], df['grades_grouped'], margins=True)
    grade_ctab['Probability_{}'.format(grade)] = round((grade_ctab[grade]/grade_ctab['All']),3)
    return grade_ctab[0:-1]


def run_graph(ctab, col, grade, stacked= True, alpha=1.0, save=False):
    '''
    df      : Dataframe
    col     : Column Name
    stacked : True(default) for Stacked Bar
    '''
    grade_title = 'Probability of Grade in Group {}'.format(grade)
    # get dataframe from crosstab function
    plotCrosstab = ctab
    
    linePlot = plotCrosstab[["Probability_{}".format(grade)]]      
    barPlot =  plotCrosstab.iloc[:,0:-2]
    ax = linePlot.plot(figsize=(20,8), marker='o', color='b')
    ax2 = barPlot.plot(kind="bar", ax=ax, rot=1, secondary_y=True, stacked=stacked, color=rainbow, alpha=alpha)
    ax.set_title(df[col].name.title() + ' vs ' + grade_title, fontsize=20, weight="bold")
    ax.set_xlabel(df[col].name.title(), fontsize=14)
    ax.set_ylabel(grade_title, color = 'b', fontsize=14)
    ax2.set_ylabel('Number of Applicants', color = 'g', fontsize=14)
    if save:
        plt.savefig(col + "_" + grade + ".png")
    plt.show()
    return linePlot
    
def display_probability_graph(col, grade, alpha=1.0, save=False):
    ctab = run_probabilities(col, grade)
#     display(ctab[col].tail(20))
    return run_graph(ctab, col, grade, alpha=alpha, save=save)


for grade in df['grades_grouped'].unique():
    display_probability_graph("emp_length", grade, alpha=0.5, save=False)

#     linePlot = display_probability_graph("annual_inc_bin", grade, alpha=0.5)
#     linePlot.plot(figsize=(20,8), marker='o', color='b', ax=ax.twinx())

# %%
#    sns.countplot(x="grade", data=df[df['purpose'] == "car"]);
def run_countplot(x, col, val, save=False):
    sns.countplot(x=x, data=df[df[col] == val].sort_values(x), palette=rainbow)
    if save:
        plt.savefig(f"countplot_{x}_{col}_{val}.png")
        plt.show()
    
for val in df['purpose'].unique()
    run_countplot("grade", "purpose", val)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/seaborn/categorical.py:1460: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)

# %%
# sns.boxplot(x="grade", y="loan_amnt", data=df)
#     plt.savefig("factorplot_grade_avg_cur_bal_purpose.png")
#     sns.factorplot(x="grade", y="bc_util", hue="default",
#                    col="home_ownership", data=df.sort_values("grade"), kind="box", size=10, aspect=1, palette=rainbow)

def run_factorplot(input_df, x, y, col, hue="default", outliers=False, outlier_percentile=70, save=False):
    if outliers:
        graph_df = input_df[input_df[y] < np.percentile(input_df[y].dropna(), outlier_percentile)]
    sns.factorplot(x=x, y=y, hue=hue, col=col, data=graph_df.sort_values(x),
                   kind="box", size=10, aspect=1, palette=rainbow)
    if save:
        plt.savefig(f"factorplot_{x}_{y}_{col}.png")
    plt.show()

run_factorplot(input_df=df, x="grade", y="annual_inc", col="purpose", hue="default",outliers=True, save=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-523-ad63ed171e53> in <module>()
#      15
#      16 run_factorplot(input_df=df, x="annual_inc", y="funded_amnt", col="bc_util",
# ---> 17                hue="default", outliers=True, save=False)
#      18
#      19
#
# <ipython-input-523-ad63ed171e53> in run_factorplot(input_df, x, y, col, hue, outliers, outlier_percentile, save)
#       9
#      10     sns.factorplot(x=x, y=y, hue=hue, col=col, data=graph_df.sort_values(x),
# ---> 11                    kind="box", size=10, aspect=1, palette=rainbow)
#      12     if save:
#      13         plt.savefig(f"factorplot_{x}_{y}_{col}.png")
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/seaborn/categorical.py in factorplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, order, hue_order, row_order, col_order, kind, size, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3506
#    3507     # Initialize the facets
# -> 3508     g = FacetGrid(**facet_kws)
#    3509
#    3510     # Draw the plot onto the facets
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/seaborn/axisgrid.py in __init__(self, data, row, col, hue, col_wrap, sharex, sharey, size, aspect, palette, row_order, col_order, hue_order, hue_kws, dropna, legend_out, despine, margin_titles, xlim, ylim, subplot_kws, gridspec_kws)
#     308                     warnings.warn(msg.format(MPL_GRIDSPEC_VERSION))
#     309
# --> 310             fig, axes = plt.subplots(nrow, ncol, **kwargs)
#     311             self.axes = axes
#     312
#
# ~/Library/Python/3.6/lib/python/site-packages/matplotlib/pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1236         else:
#    1237             subplot_kw['sharey'] = axarr[sys[i]]
# -> 1238         axarr[i] = fig.add_subplot(gs[i // ncols, i % ncols], **subplot_kw)
#    1239
#    1240     # returned axis array will be always 2-d, even if nrows=ncols=1
#
# ~/Library/Python/3.6/lib/python/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1003
#    1004             # try to find the axes with this key in the stack
# -> 1005             ax = self._axstack.get(key)
#    1006
#    1007             if ax is not None:
#
# ~/Library/Python/3.6/lib/python/site-packages/matplotlib/figure.py in get(self, key)
#      89         If it is not present, return None.
#      90         """
# ---> 91         item = dict(self._elements).get(key)
#      92         if item is None:
#      93             return None
#
# ~/Library/Python/3.6/lib/python/site-packages/matplotlib/gridspec.py in __eq__(self, other)
#     472         if not (hasattr(other, '_gridspec') and
#     473                 hasattr(other, 'num1') and
# --> 474                 hasattr(other, 'num2')):
#     475             return False
#     476         return all((self._gridspec == other._gridspec,
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     330                 pass
#     331             else:
# --> 332                 return printer(obj)
#     333             # Finally look for special method names
#     334             method = get_real_method(obj, self.print_method)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     235
#     236     if 'png' in formats:
# --> 237         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     238     if 'retina' in formats or 'png2x' in formats:
#     239         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     119
#     120     bytes_io = BytesIO()
# --> 121     fig.canvas.print_figure(bytes_io, **kw)
#     122     data = bytes_io.getvalue()
#     123     if fmt == 'svg':
#
# ~/Library/Python/3.6/lib/python/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2190                     orientation=orientation,
#    2191                     dryrun=True,
# -> 2192                     **kwargs)
#    2193                 renderer = self.figure._cachedRenderer
#    2194                 bbox_inches = self.figure.get_tightbbox(renderer)
#
# ~/Library/Python/3.6/lib/python/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     543
#     544     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 545         FigureCanvasAgg.draw(self)
#     546         renderer = self.get_renderer()
#     547         original_dpi = renderer.dpi
#
# ~/Library/Python/3.6/lib/python/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     457         if __debug__: verbose.report('FigureCanvasAgg.draw', 'debug-annoying')
#     458
# --> 459         self.renderer = self.get_renderer(cleared=True)
#     460         # acquire a lock on the shared font cache
#     461         RendererAgg.lock.acquire()
#
# ~/Library/Python/3.6/lib/python/site-packages/matplotlib/backends/backend_agg.py in get_renderer(self, cleared)
#     474
#     475         if need_new_renderer:
# --> 476             self.renderer = RendererAgg(w, h, self.figure.dpi)
#     477             self._lastKey = key
#     478         elif cleared:
#
# ~/Library/Python/3.6/lib/python/site-packages/matplotlib/backends/backend_agg.py in __init__(self, width, height, dpi)
#      91         self.height = height
#      92         if __debug__: verbose.report('RendererAgg.__init__ width=%s, height=%s'%(width, height), 'debug-annoying')
# ---> 93         self._renderer = _RendererAgg(int(width), int(height), dpi, debug=False)
#      94         self._filter_renderers = []
#      95
#
# ValueError: Image size of 850320x720 pixels is too large. It must be less than 2^16 in each direction.

# %%
ctabs = {}

def do_crosstab(col):
    ctab = pd.crosstab(df[col], df['loan_status'],margins=True)
    ctab['Probability_Charged Off'] = round((ctab['Charged Off']/ctab['All']),3)
    ctab = ctab[0:-1]

    return ctab

# Probability of charge off
def bivariate_prob(col, stacked= True, save=False):
    '''
    df      : Dataframe
    col     : Column Name
    stacked : True(default) for Stacked Bar
    '''
    # get dataframe from crosstab function
    plotCrosstab = ctabs[col]
    
    linePlot = plotCrosstab[['Probability_Charged Off']]      
    barPlot =  plotCrosstab.iloc[:,0:-2]
    ax = linePlot.plot(figsize=(20,8), marker='o',color = 'b')
    ax2 = barPlot.plot(kind='bar',ax = ax,rot=1,secondary_y=True,stacked=stacked, alpha=0.5)
    ax.set_title(df[col].name.title() + ' vs Probability Charge Off', fontsize=20, weight="bold")
    ax.set_xlabel(df[col].name.title(), fontsize=14)
    ax.set_ylabel('Probability of Charged off',color = 'b', fontsize=14)
    ax2.set_ylabel('Number of Applicants',color = 'g', fontsize=14)
    if save:
        plt.savefig("bivariate_prob_of_default_" + col + ".png")
    plt.show()

def display_bivariate_prob(col, save=False):
    ctabs[col] = do_crosstab(col)
    display(ctabs[col].tail(20))
    return bivariate_prob(col=col, save=save)

# %%
display_bivariate_prob("last_credit_pull_d_year", save=True)
# Out:
# loan_status              Charged Off  Current  Fully Paid  In Grace Period  \
# last_credit_pull_d_year
# 2012                              34        0         508                0
# 2013                             179        0        3240                0
# 2014                             388        1        8268                0
# 2015                             318        3       17069                0
# 2016                           15613        9       26016                0
# 2017                            6073       51       30746                0
# 2018                            6805     5134       67427              128
#
# loan_status              Late (16-30 days)  Late (31-120 days)    All  \
# last_credit_pull_d_year
# 2012                                     0                   0    542
# 2013                                     0                   0   3419
# 2014                                     0                   0   8657
# 2015                                     0                   0  17390
# 2016                                     0                   0  41638
# 2017                                     0                   0  36870
# 2018                                    31                 130  79655
#
# loan_status              Probability_Charged Off
# last_credit_pull_d_year
# 2012                                       0.063
# 2013                                       0.052
# 2014                                       0.045
# 2015                                       0.018
# 2016                                       0.375
# 2017                                       0.165
# 2018                                       0.085

# %%
categorical = df.select_dtypes(object)
numerical = df.select_dtypes(include = ["float64", "int64"])
categorical['default'] = numerical['default'].astype(object)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
numerical = numerical.apply(lambda x: np.log(x) if np.mean(x) > 1000 else x, axis=0)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.

# %%
numerical['grade'] = df.sort_values('grade')['grade'].astype("category").cat.codes
numerical_cov = numerical.cov()
numerical_cov.dropna(how="all", inplace=True)

# %%
import numpy as np
from operator import itemgetter

def run_covariance_matrix(target):

    n_target_cov = dict(numerical_cov[target])
    median_of_n_target_cov = np.median(list(n_target_cov.values()))       
    filtered_target_cov_columns = {k: v for k, v in n_target_cov.items() if abs(v) > median_of_n_target_cov}
    return sorted(filtered_target_cov_columns.items(), key=itemgetter(1), reverse=True)

# %%
keys = [item[0] for item in run_covariance_matrix("grade")]

# %%
column_info('num_sats')
# Out:
# Number of satisfactory accounts
# values: [14.  3.  4. 10.  9. 16. 17. 12.  8.  7.  6.  5. 15. 29. 11. 13. 20. 19.
#  21. 25. 18. 30. 27. 22. 23. 24. 40. 26.  2. 28. 31.  1. 37. 32. 33. 42.
#  41.  0. 34. 39. 36. 35. 45. 38. 49. 53. 51. 43. 62. 44. 48. 50. 52. 46.
#  nan]
# length: 55
# max: 62.0

# %%
run_covariance_matrix("default")
# Out:
# [('hardship_payoff_balance_amount', 262.03864873417734),
#  ('loan_amnt', 158.1519402262483),
#  ('funded_amnt', 157.80454134622332),
#  ('funded_amnt_inv', 157.43933823520848),
#  ('recoveries', 155.53902353663972),
#  ('collection_recovery_fee', 17.56629595425876),
#  ('orig_projected_additional_accrued_interest', 12.113343989769822),
#  ('settlement_amount', 11.722312965272568),
#  ('hardship_last_payment_amount', 5.505436708860757),
#  ('hardship_amount', 4.210424050632912),
#  ('installment', 3.203024502625995),
#  ('hardship_dpd', 1.2474683544303804),
#  ('percent_bc_gt_75', 0.8294258514181484),
#  ('bc_util', 0.6128196947809174),
#  ('int_rate', 0.33401997274767237),
#  ('mths_since_last_record', 0.29401830064654394),
#  ('dti', 0.2162282368725705),
#  ('default', 0.1318648362131925),
#  ('delinq_amnt', 0.09817368356487186),
#  ('grade', 0.09516338877062862),
#  ('mths_since_last_major_derog', 0.08689126267356598),
#  ('acc_open_past_24mths', 0.08024413003329843),
#  ('num_rev_tl_bal_gt_0', 0.060580687746471316),
#  ('num_actv_rev_tl', 0.05986520946785786),
#  ('installment_bin', 0.04338757304281539),
#  ('num_tl_op_past_12m', 0.0428599286644575),
#  ('num_op_rev_tl', 0.03820711974963305),
#  ('num_sats', 0.032596627467614124),
#  ('open_acc', 0.028346496786646615),
#  ('bc_util_bin', 0.025468666159005008),
#  ('inq_last_6mths', 0.022818659568233472),
#  ('num_actv_bc_tl', 0.021473464653000176),
#  ('mths_since_recent_bc_dlq', 0.020335206020586773),
#  ('pct_tl_nvr_dlq', 0.014023183623981585),
#  ('num_bc_sats', 0.009061406950439721),
#  ('delinq_2yrs', 0.0010754019517810673),
#  ('num_accts_ever_120_pd', 0.0005885979644020912),
#  ('num_tl_90g_dpd_24m', 0.0004155794776929601),
#  ('pub_rec_bankruptcies', 0.0003155320052577755),
#  ('num_rev_accts', -0.002049890486137928),
#  ('settlement_percentage', -0.0037714974640393755),
#  ('mths_since_recent_revol_delinq', -0.0058903869820371435),
#  ('mths_since_last_delinq', -0.005924257313503019),
#  ('num_il_tl', -0.010268823948201632),
#  ('num_bc_tl', -0.011717714540365362),
#  ('settlement_term', -0.02199883595244092),
#  ('mort_acc', -0.0342735433792258),
#  ('total_acc', -0.05075762459966437),
#  ('mths_since_recent_inq', -0.11049422216249666),
#  ('mo_sin_rcnt_tl', -0.2001701035071028),
#  ('mo_sin_rcnt_rev_tl_op', -0.31884998255223174),
#  ('mo_sin_old_il_acct', -0.46260385675518806),
#  ('mths_since_recent_bc', -0.5244758744343541),
#  ('mo_sin_old_rev_tl_op', -1.333293938947749),
#  ('tot_coll_amt', -1.575690592834297),
#  ('out_prncp_inv', -11.38722725735675),
#  ('out_prncp', -11.391872102065266),
#  ('revol_bal', -95.08602129457013),
#  ('total_il_high_credit_limit', -151.68452653696036),
#  ('total_bal_ex_mort', -152.85599127724544),
#  ('bc_open_to_buy', -336.1878496168284),
#  ('avg_cur_bal', -357.81648547994445),
#  ('total_bc_limit', -433.1611374999758),
#  ('total_rev_hi_lim', -477.2716343457266),
#  ('last_pymnt_amnt', -575.5307088114673),
#  ('total_pymnt_inv', -952.3432639709874),
#  ('total_pymnt', -953.2545832780484),
#  ('annual_inc', -981.5917171455472),
#  ('tot_cur_bal', -2936.778648579784),
#  ('tot_hi_cred_lim', -3638.8315723220844)]

# %%
df['last_credit_pull_d_year'], df['last_credit_pull_d_year'] = df['last_credit_pull_d'].str.split("-", 1).str

# %%
categorical.columns
# Out:
# Index(['term', 'grade', 'sub_grade', 'emp_length', 'home_ownership',
#        'verification_status', 'issue_d', 'loan_status', 'pymnt_plan',
#        'purpose', 'addr_state', 'revol_util', 'initial_list_status',
#        'last_credit_pull_d', 'application_type', 'hardship_flag',
#        'hardship_type', 'hardship_reason', 'hardship_status',
#        'hardship_start_date', 'hardship_end_date', 'payment_plan_start_date',
#        'hardship_loan_status', 'disbursement_method', 'debt_settlement_flag',
#        'debt_settlement_flag_date', 'settlement_status', 'settlement_date',
#        'issue_month', 'issue_year', 'default'],
#       dtype='object')

# %% [markdown]
# # Feature Engineering for Classification

# %%
to_dummies = [
        "purpose",
        "home_ownership",
        "emp_length",
        "grade",
        "mo_sin_old_rev_tl_op_bin",
        "last_credit_pull_d_year"
]

def merge_dummies(dummies, df):
    for column in dummies:
        df = df.merge(pd.get_dummies(df[column], prefix="dummy_" + column), left_index=True, right_index=True)
    return df

# %%
df = merge_dummies(to_dummies, df)

# %%
column_desc['last_credit_pull_d']
# Out:
# 'The most recent month LC pulled credit for this loan'

# %%
dummy_columns = [col for col in df.columns if "dummy" in col]

# %%
model_features = [
    "loan_amnt",
    "funded_amnt",
    "funded_amnt_inv",
    "installment",
    "percent_bc_gt_75",
    "bc_util",
    "dti",
    "int_rate",
    "num_sats",
    "revol_bal",
    "total_il_high_credit_limit",
    "total_bal_ex_mort",
    "bc_open_to_buy",
    "avg_cur_bal",
    "total_bc_limit",
    "last_pymnt_amnt",
    "total_pymnt_inv",
    "total_pymnt",
    "annual_inc",
    "tot_cur_bal",
    "tot_hi_cred_lim",
]

model_features.extend(dummy_columns)

# %%
from sklearn.decomposition import PCA
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

X = df[model_features].drop(dummy_grade_columns, axis=1)
y = df['default']

X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
dummy_grade_columns = [col for col in df.columns if 'dummy_grade' in col]

# %%
# pca = PCA(n_components=5, svd_solver='full')

# pca.fit(X_train.dropna(axis=1))

# plt.figure(1, figsize=(8, 6))
# plt.clf()
# # plt.axes([.2, .2, .7, .7])
# plt.plot(pca.explained_variance_, linewidth=2)
# # plt.axis('tight')
# plt.xlabel('n_components')
# plt.ylabel('explained_variance_')

# %%
logreg = LogisticRegression()
# logistic.fit(X_train, y_train)

# %%
# Out:
# array([0.001, 0.112, 0.223, 0.334, 0.445, 0.556, 0.667, 0.778, 0.889,
#        1.   ])

# %%
# Prediction
C_param_range = [0.001,0.01,0.1,1,10,100]


# Parameters of pipelines can be set using ‘__’ separated parameter names:
estimator = GridSearchCV(logreg, param_grid={"C": np.linspace(0.001, 1, 10)})

# %%
estimator.fit(X_train.fillna(0), y_train.fillna(0))
# Out:
# GridSearchCV(cv=None, error_score='raise',
#        estimator=LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'C': array([0.001, 0.112, 0.223, 0.334, 0.445, 0.556, 0.667, 0.778, 0.889,
#        1.   ])},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
y_pred = estimator.predict(X_test.fillna(0))

print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99     37811
#           1       0.98      0.86      0.92      6957
#
# avg / total       0.98      0.98      0.98     44768
#
# [[37696   115]
#  [  960  5997]]

# %%
estimator.score(X_test.fillna(0), y_test.fillna(0))
# Out:
# 0.9759873123659757
